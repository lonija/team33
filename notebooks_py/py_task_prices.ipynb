# %% [markdown]
# **Easy Level**
#
# In this level, you will read the data from prices.txt
# (see additional files),  compute the total price of all items, and count the total number of purchased items.
#
# ! If you don't know how to deal with non integer characters, remove them manually from the file !
#
# **Medium Level**
#
# In this level, we will extend the program to skip rows that contain anything other than a number in the code.
# (Modify your program in such a way that all rows that contain something else than a number, are skipped.)

# %%
filename = "/content/prices_numbers.txt"

#counters
total_price = 0.0
item_count = 0

try:
    with open(filename, "r") as file:
        content = file.readlines()

    for line in content:
        line = line.rstrip('\n')
        price = float(line)
        #use of counters
        total_price += price
        item_count += 1

    print(f"Total price: {total_price}")
    print(f"Total count: {item_count}")

except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
# Out:
# Total price: 17.32
# Total count: 5
